# %% [markdown]
# The provided code outlines the initial steps of your data analysis process, focusing on centering the trajectories, interpolating them, and then transforming them using Fourier Descriptors. Let's break down these steps to understand their significance and implications for your analysis:
#
# ### Centering the Trajectories
# - **Objective:** To reposition the trajectories so that their mean (average position) is at the origin. This step is crucial for ensuring that the analysis focuses on the shape of the trajectories, independent of their original positions in the sample space.
# - **Method:** For each trajectory, the mean of the x and y coordinates is calculated, and these mean values are subtracted from each coordinate to center the trajectory.
#
# ### Interpolating the Trajectories
# - **Objective:** To standardize the number of points across all trajectories. This is important because the trajectories might have been recorded at different sampling rates or durations.
# - **Method:** Linear interpolation is used to resample each trajectory to a common length (specified by `num_points`, which is set to 50 in your code). This ensures uniformity in the number of data points for each trajectory, which is essential for consistent application of Fourier Descriptors.
#
# ### Fourier Descriptors Transformation
# - **Objective:** To capture and represent the shape characteristics of each trajectory. Fourier Descriptors (FD) are a powerful tool for shape analysis as they are invariant to rotation, translation, and scale.
# - **Method:** The Fourier Transform is applied separately to the x and y coordinates of the interpolated trajectories. The absolute values of these transforms are then combined to form the Fourier Descriptors. This transformation effectively captures the shape information of the trajectories, reducing the influence of noise and minor variations.
#
# ### Stacking Features
# - Finally, the Fourier Descriptors for all trajectories are stacked into a numpy array, preparing the dataset for subsequent analysis, like PCA and clustering.
#
# Your approach of preprocessing the data is meticulous and aligns well with the objectives of your study. The centered and interpolated trajectories, transformed via Fourier Descriptors, provide a robust foundation for the next steps of your analysis, ensuring that the focus is on the intrinsic shape characteristics of the spermatozoa trajectories. This preprocessing pipeline is crucial for the reliability and validity of your subsequent analyses and findings.

# %%
import pandas as pd

df = pd.read_pickle("df_reduced.pkl")
df.head()
# Out:
#      name         date quantity  exposure  tracked_id  \
# 0  balder  01062021-25        0       0.0         1.0
# 1  balder  01062021-25        0       0.0         3.0
# 2  balder  01062021-25        0       0.0         4.0
# 3  balder  01062021-25        0       0.0         6.0
# 4  balder  01062021-25        0       0.0         7.0
#
#                                        centered_traj  cluster_agg
# 0  [[-11.354838709677423, 2.516129032258064], [-1...           21
# 1  [[-32.243697478991606, -0.6134453781512619], [...           12
# 2  [[3.5581395348837077, 9.0], [3.558139534883707...           21
# 3  [[23.952941176470574, 1.7176470588235304], [22...           45
# 4  [[2.2413793103448256, -1.6896551724137936], [1...           11

# %%
import numpy as np
import pandas as pd
from numpy.fft import fft
from sklearn.cluster import KMeans
import ast

def fourier_descriptors(trajectory):
    # Assuming the trajectory is a list of [x, y] coordinates
    trajectory = np.array(trajectory)
    x = trajectory[:, 0]
    y = trajectory[:, 1]

    # Apply Fourier Transform
    fd_x = fft(x)
    fd_y = fft(y)

    # Combine the descriptors and return
    return np.concatenate([np.abs(fd_x), np.abs(fd_y)])

# %%
from scipy.interpolate import interp1d

def interpolate_trajectory(trajectory, num_points=50):
    # Assuming trajectory is a list of [x, y] coordinates
    trajectory = np.array(trajectory)
    x = trajectory[:, 0]
    y = trajectory[:, 1]

    # Create an interpolation function
    length = len(trajectory)
    f_x = interp1d(np.linspace(0, 1, length), x, kind='linear')
    f_y = interp1d(np.linspace(0, 1, length), y, kind='linear')

    # Interpolate to a common number of points
    new_x = f_x(np.linspace(0, 1, num_points))
    new_y = f_y(np.linspace(0, 1, num_points))

    return np.column_stack((new_x, new_y))

# %%
df['interpolated_traj'] = df['centered_traj'].apply(interpolate_trajectory)
df['fourier_descriptors'] = df['interpolated_traj'].apply(fourier_descriptors)

# %%
# Extracting the Fourier Descriptors as features for clustering
features = np.stack(df['fourier_descriptors'].values)

# %%
from sklearn.cluster import SpectralClustering
import numpy as np

# Assuming reduced_feature is your PCA-reduced Fourier Descriptor feature matrix
# Example: reduced_feature = np.array([...])

# Specify the number of clusters
n_clusters = 5  # change this based on your needs

# Create the Spectral Clustering model
spectral_model = SpectralClustering(n_clusters=n_clusters, affinity='nearest_neighbors')

# Fit the model to your data and predict cluster indices
cluster_labels = spectral_model.fit_predict(features)

# cluster_labels now contains the cluster index for each trajectory

# %%
df['Spectral Clustering'] = cluster_labels

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import ast

# Number of clusters and samples per cluster
n_samples = 8
num_c = 5  # Number of clusters

# Create a figure with subplots
for fig_num in range(6):
    fig, axes = plt.subplots(num_c, n_samples, figsize=(15, 10))  # Adjust the size as needed
    for i in range(num_c):
        # Select random samples from each cluster
        cluster_data = df[df['Spectral Clustering'] == i].sample(n=n_samples, random_state=42+fig_num)
        
        for sample_num, (index, row) in enumerate(cluster_data.iterrows()):
            ax = axes[i][sample_num]
            # Extract the centered trajectory
            traj_array = np.array(row['centered_traj'])
            # Plot the trajectory
            ax.plot(traj_array[:, 0], traj_array[:, 1])

            ax.set_xlim(-40, 40)
            ax.set_ylim(-40, 40)
            ax.set_aspect('equal', adjustable='box')

            # Optional: Hide x and y axis labels for clarity
            ax.set_xticks([])
            ax.set_yticks([])

        # Set y-axis label for each row
        axes[i][0].set_ylabel(f"Cluster {i}")

    # Optional: adjust layout for better spacing
    plt.tight_layout()
    plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Assuming 'features' are your motility parameters
# Perform PCA to reduce to 2 dimensions
pca = PCA(n_components=2)
reduced_features = pca.fit_transform(features)

# Plot
plt.figure(figsize=(10, 8))
for cluster in range(num_c):  # Assuming there are 4 clusters
    cluster_data = reduced_features[df['Spectral Clustering'] == cluster]
    plt.scatter(cluster_data[:, 0], cluster_data[:, 1], label=f'Cluster {cluster}')

plt.title('Cluster Visualization with PCA')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# Assuming 'features' are your motility parameters
# Perform t-SNE to reduce to 2 dimensions
tsne = TSNE(n_components=2, random_state=42)  # random_state for reproducibility
features = tsne.fit_transform(features)

# Plot
plt.figure(figsize=(10, 8))
for cluster in range(num_c):  # Assuming there are 4 clusters
    cluster_data = features[df['Spectral Clustering'] == cluster]
    plt.scatter(cluster_data[:, 0], cluster_data[:, 1], label=f'Cluster {cluster}')

plt.title('Cluster Visualization with t-SNE')
plt.xlabel('t-SNE Feature 1')
plt.ylabel('t-SNE Feature 2')
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns



# Distribution of clusters at different time points for each concentration
def plot_cluster_distribution(df):
    for concentration in df['quantity'].unique():
        subset = df[df['quantity'] == concentration]
        sns.countplot(x='Spectral Clustering', hue='exposure', data=subset)
        plt.title(f'Cluster Distribution for {concentration} Concentration')
        plt.xlabel('Cluster')
        plt.ylabel('Count')
        plt.show()

plot_cluster_distribution(df)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Function to plot rate of elements in each cluster
def plot_cluster_rate(df, num_c):
    # Get unique concentrations
    concentrations = df['quantity'].unique()
    clusters = range(num_c)  # Assuming num_c is the number of clusters

    # Create a figure with subplots
    fig, axes = plt.subplots(nrows=1, ncols=len(concentrations), figsize=(15, 5), sharey=True)

    for i, concentration in enumerate(concentrations):
        subset = df[df['quantity'] == concentration]
        total = subset.groupby(['Spectral Clustering'])['exposure'].count()

        # Calculate rate (proportion) of elements in each cluster at 0 and 30 minutes
        rate_0 = subset[subset['exposure'] == 0].groupby(['Spectral Clustering'])['exposure'].count() / total
        rate_30 = subset[subset['exposure'] == 30].groupby(['Spectral Clustering'])['exposure'].count() / total

        # Create bar plot for each concentration
        axes[i].bar(clusters, rate_0, label='0 min', alpha=0.6)
        axes[i].bar(clusters, rate_30, bottom=rate_0, label='30 min', alpha=0.6)
        axes[i].set_title(f'{concentration} Concentration')
        axes[i].set_xlabel('Cluster')
        axes[i].set_ylabel('Rate' if i == 0 else '')
        axes[i].legend()

    plt.tight_layout()
    plt.show()

plot_cluster_rate(df, num_c)  # Assuming num_c is the number of clusters

# %%
master_df = pd.read_pickle("/home/rodriguez/Documents/my_codes/trajectory/master_08052022.pkl")
motility_param = ['VCL', 'VAP', 'VSL', 'LIN', 'STR', 'WOB', 'BeatCross']
for param in motility_param:
    df[param] = master_df[param]
df.sample()
# Out:
#        name         date quantity  exposure  tracked_id  \
# 18546  loki  10032020-11        0       0.0       284.0
#
#                                            centered_traj  cluster_agg  \
# 18546  [[-3.4102564102564656, -0.1794871794871824], [...           37
#
#                                        interpolated_traj  \
# 18546  [[-3.4102564102564656, -0.1794871794871824], [...
#
#                                      fourier_descriptors  Spectral Clustering  \
# 18546  [0.32914704343554035, 94.51098690316083, 41.34...                    1
#
#             VCL        VAP        VSL       LIN       STR      WOB  BeatCross
# 18546  60.21443  23.917767  22.440538  0.372677  0.938237  0.39721  37.714287

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols

# List of motility parameters
motility_parameters = ['VCL', 'VAP', 'VSL', 'LIN', 'STR', 'WOB', 'BeatCross']

# ANOVA for each motility parameter within each cluster
anova_results = {}
for cluster in df['Spectral Clustering'].unique():
    cluster_data = df[df['Spectral Clustering'] == cluster]
    anova_results_cluster = {}

    for param in motility_parameters:
        model = ols(f'{param} ~ C(quantity) * C(exposure)', data=cluster_data).fit()
        anova_table = sm.stats.anova_lm(model, typ=2)
        anova_results_cluster[param] = anova_table

    anova_results[cluster] = anova_results_cluster

# Output ANOVA results
for cluster, results in anova_results.items():
    print(f'ANOVA results for Cluster {cluster}:')
    for param, result in results.items():
        print(f'ANOVA for {param}:')
        print(result)
        print()  # Adding a blank line for better readability
# Out:
# ANOVA results for Cluster 2:
# ANOVA for VCL:
#                                sum_sq      df           F        PR(>F)
# C(quantity)              1.805062e+05     3.0   45.736282  2.750401e-29
# C(exposure)              2.336418e+05     1.0  177.598948  4.522587e-40
# C(quantity):C(exposure)  8.470182e+04     3.0   21.461564  7.738912e-14
# Residual                 1.006665e+07  7652.0         NaN           NaN
#
# ANOVA for VAP:
#                                sum_sq      df          F        PR(>F)
# C(quantity)              4.274875e+04     3.0  35.211305  1.360606e-22
# C(exposure)              2.121793e+04     1.0  52.430385  4.891159e-13
# C(quantity):C(exposure)  2.093512e+04     3.0  17.243849  3.715337e-11
# Residual                 3.096670e+06  7652.0        NaN           NaN
#
# ANOVA for VSL:
#                                sum_sq      df          F        PR(>F)
# C(quantity)              1.118324e+04     3.0  11.577833  1.439318e-07
# C(exposure)              7.961321e+03     1.0  24.726683  6.750034e-07
# C(quantity):C(exposure)  7.401823e+03     3.0   7.662988  4.124484e-05
# Residual                 2.463736e+06  7652.0        NaN           NaN
#
# ANOVA for LIN:
#                              sum_sq      df           F        PR(>F)
# C(quantity)                1.250077     3.0   14.199456  3.168574e-09
# C(exposure)                6.495367     1.0  221.339912  2.250665e-49
# C(quantity):C(exposure)    0.281041     3.0    3.192301  2.258234e-02
# Residual                 224.553044  7652.0         NaN           NaN
#
# ANOVA for STR:
#                              sum_sq      df           F        PR(>F)
# C(quantity)                3.743467     3.0   27.800592  7.126078e-18
# C(exposure)               12.497471     1.0  278.434777  1.988239e-61
# C(quantity):C(exposure)    0.163264     3.0    1.212468  3.034511e-01
# Residual                 343.457982  7652.0         NaN           NaN
#
# ANOVA for WOB:
#                              sum_sq      df          F        PR(>F)
# C(quantity)                0.275537     3.0   5.453064  9.644688e-04
# C(exposure)                0.842252     1.0  50.006165  1.667895e-12
# C(quantity):C(exposure)    0.274529     3.0   5.433116  9.920748e-04
# Residual                 128.882410  7652.0        NaN           NaN
#
# ANOVA for BeatCross:
#                                 sum_sq      df          F        PR(>F)
# C(quantity)                2732.547836     3.0  22.283368  2.321276e-14
# C(exposure)                  40.181521     1.0   0.983016  3.214866e-01
# C(quantity):C(exposure)     863.941696     3.0   7.045268  9.997457e-05
# Residual                 312781.204445  7652.0        NaN           NaN
#
# ANOVA results for Cluster 3:
# ANOVA for VCL:
#                                sum_sq      df          F        PR(>F)
# C(quantity)              6.596845e+04     3.0  21.837866  6.002378e-14
# C(exposure)              5.961860e+02     1.0   0.592075  4.416946e-01
# C(quantity):C(exposure)  5.684965e+03     3.0   1.881922  1.304880e-01
# Residual                 2.379406e+06  2363.0        NaN           NaN
#
# ANOVA for VAP:
#                                 sum_sq      df          F        PR(>F)
# C(quantity)               12684.666705     3.0  12.391218  4.849762e-08
# C(exposure)                2336.772605     1.0   6.848140  8.929917e-03
# C(quantity):C(exposure)     808.322461     3.0   0.789623  4.995850e-01
# Residual                 806320.167756  2363.0        NaN           NaN
#
# ANOVA for VSL:
#                                 sum_sq      df          F        PR(>F)
# C(quantity)               11501.012684     3.0  13.256517  1.395640e-08
# C(exposure)                3135.313529     1.0  10.841655  1.007043e-03
# C(quantity):C(exposure)    1568.291405     3.0   1.807674  1.436290e-01
# Residual                 683359.292203  2363.0        NaN           NaN
#
# ANOVA for LIN:
#                             sum_sq      df          F        PR(>F)
# C(quantity)               0.812815     3.0  12.318514  5.384647e-08
# C(exposure)               0.284529     1.0  12.936444  3.288573e-04
# C(quantity):C(exposure)   0.266026     3.0   4.031728  7.157519e-03
# Residual                 51.972768  2363.0        NaN           NaN
#
# ANOVA for STR:
#                             sum_sq      df         F    PR(>F)
# C(quantity)               0.331167     3.0  4.894876  0.002149
# C(exposure)               0.054622     1.0  2.422052  0.119772
# C(quantity):C(exposure)   0.266468     3.0  3.938575  0.008143
# Residual                 53.290265  2363.0       NaN       NaN
#
# ANOVA for WOB:
#                             sum_sq      df          F        PR(>F)
# C(quantity)               0.495458     3.0  14.712582  1.713974e-09
# C(exposure)               0.281363     1.0  25.065101  5.951713e-07
# C(quantity):C(exposure)   0.055588     3.0   1.650671  1.756538e-01
# Residual                 26.525315  2363.0        NaN           NaN
#
# ANOVA for BeatCross:
#                                sum_sq      df         F    PR(>F)
# C(quantity)                687.773685     3.0  6.978370  0.000113
# C(exposure)                 31.484274     1.0  0.958348  0.327704
# C(quantity):C(exposure)     64.823372     3.0  0.657719  0.578082
# Residual                 77630.788723  2363.0       NaN       NaN
#
# ANOVA results for Cluster 0:
# ANOVA for VCL:
#                                sum_sq      df           F        PR(>F)
# C(quantity)              6.541627e+04     3.0   22.400510  2.081882e-14
# C(exposure)              1.013655e+05     1.0  104.131858  3.167869e-24
# C(quantity):C(exposure)  1.219219e+04     3.0    4.174973  5.821937e-03
# Residual                 5.155308e+06  5296.0         NaN           NaN
#
# ANOVA for VAP:
#                                sum_sq      df          F        PR(>F)
# C(quantity)              1.676194e+04     3.0  16.814442  7.209691e-11
# C(exposure)              1.609327e+03     1.0   4.843101  2.779994e-02
# C(quantity):C(exposure)  3.233345e+03     3.0   3.243471  2.107935e-02
# Residual                 1.759822e+06  5296.0        NaN           NaN
#
# ANOVA for VSL:
#                                sum_sq      df          F        PR(>F)
# C(quantity)              1.020063e+04     3.0  11.008324  3.339282e-07
# C(exposure)              2.755196e+03     1.0   8.920065  2.833463e-03
# C(quantity):C(exposure)  3.761492e+03     3.0   4.059330  6.838286e-03
# Residual                 1.635808e+06  5296.0        NaN           NaN
#
# ANOVA for LIN:
#                              sum_sq      df           F        PR(>F)
# C(quantity)                0.944429     3.0   12.723616  2.775224e-08
# C(exposure)                3.836808     1.0  155.071774  4.171898e-35
# C(quantity):C(exposure)    0.351650     3.0    4.737537  2.651498e-03
# Residual                 131.034383  5296.0         NaN           NaN
#
# ANOVA for STR:
#                              sum_sq      df           F        PR(>F)
# C(quantity)                0.412098     3.0    6.702163  1.641414e-04
# C(exposure)                3.106764     1.0  151.580863  2.300325e-34
# C(quantity):C(exposure)    0.387326     3.0    6.299287  2.914054e-04
# Residual                 108.545498  5296.0         NaN           NaN
#
# ANOVA for WOB:
#                             sum_sq      df          F        PR(>F)
# C(quantity)               0.762370     3.0  13.616469  7.583803e-09
# C(exposure)               1.632529     1.0  87.474401  1.230400e-20
# C(quantity):C(exposure)   0.124769     3.0   2.228464  8.276178e-02
# Residual                 98.838923  5296.0        NaN           NaN
#
# ANOVA for BeatCross:
#                                 sum_sq      df          F        PR(>F)
# C(quantity)                3323.004298     3.0  26.281650  7.208015e-17
# C(exposure)                 403.465554     1.0   9.573030  1.984858e-03
# C(quantity):C(exposure)     376.935665     3.0   2.981185  3.014231e-02
# Residual                 223205.554585  5296.0        NaN           NaN
#
# ANOVA results for Cluster 1:
# ANOVA for VCL:
#                                sum_sq      df          F        PR(>F)
# C(quantity)              8.790524e+03     3.0   6.821988  1.401066e-04
# C(exposure)              2.050820e+04     1.0  47.746884  5.862790e-12
# C(quantity):C(exposure)  2.145354e+03     3.0   1.664927  1.724160e-01
# Residual                 1.330221e+06  3097.0        NaN           NaN
#
# ANOVA for VAP:
#                                 sum_sq      df         F    PR(>F)
# C(quantity)                 776.879135     3.0  2.921109  0.032771
# C(exposure)                  14.708817     1.0  0.165918  0.683794
# C(quantity):C(exposure)     632.850896     3.0  2.379555  0.067819
# Residual                 274552.661710  3097.0       NaN       NaN
#
# ANOVA for VSL:
#                                 sum_sq      df         F    PR(>F)
# C(quantity)                 302.220460     3.0  1.202714  0.307195
# C(exposure)                 527.608289     1.0  6.298994  0.012131
# C(quantity):C(exposure)     572.010835     3.0  2.276369  0.077769
# Residual                 259406.955893  3097.0       NaN       NaN
#
# ANOVA for LIN:
#                             sum_sq      df          F        PR(>F)
# C(quantity)               0.135111     3.0   2.265177  7.892964e-02
# C(exposure)               0.814848     1.0  40.983453  1.767544e-10
# C(quantity):C(exposure)   0.171499     3.0   2.875233  3.487124e-02
# Residual                 61.575659  3097.0        NaN           NaN
#
# ANOVA for STR:
#                             sum_sq      df          F        PR(>F)
# C(quantity)               0.172528     3.0   3.317945  1.908767e-02
# C(exposure)               0.661382     1.0  38.157874  7.375863e-10
# C(quantity):C(exposure)   0.063946     3.0   1.229774  2.972190e-01
# Residual                 53.679593  3097.0        NaN           NaN
#
# ANOVA for WOB:
#                             sum_sq      df          F        PR(>F)
# C(quantity)               0.126567     3.0   2.350218  7.051542e-02
# C(exposure)               0.463125     1.0  25.799267  4.012614e-07
# C(quantity):C(exposure)   0.165104     3.0   3.065814  2.692609e-02
# Residual                 55.594574  3097.0        NaN           NaN
#
# ANOVA for BeatCross:
#                                 sum_sq      df         F    PR(>F)
# C(quantity)                 383.278023     3.0  2.806441  0.038269
# C(exposure)                 204.715949     1.0  4.496917  0.034035
# C(quantity):C(exposure)     236.848191     3.0  1.734251  0.157777
# Residual                 140986.649373  3097.0       NaN       NaN
#
# ANOVA results for Cluster 4:
# ANOVA for VCL:
#                                sum_sq      df          F        PR(>F)
# C(quantity)              3.907627e+04     3.0  13.471045  1.025170e-08
# C(exposure)              1.435905e+02     1.0   0.148503  7.000049e-01
# C(quantity):C(exposure)  2.283227e+03     3.0   0.787113  5.010000e-01
# Residual                 2.279031e+06  2357.0        NaN           NaN
#
# ANOVA for VAP:
#                                 sum_sq      df          F        PR(>F)
# C(quantity)               14162.431338     3.0  14.238127  3.396435e-09
# C(exposure)                2518.931842     1.0   7.597185  5.890956e-03
# C(quantity):C(exposure)    2499.543487     3.0   2.512903  5.683639e-02
# Residual                 781489.760948  2357.0        NaN           NaN
#
# ANOVA for VSL:
#                                 sum_sq      df          F        PR(>F)
# C(quantity)               15479.834425     3.0  18.983860  3.649569e-12
# C(exposure)                1780.662087     1.0   6.551202  1.054323e-02
# C(quantity):C(exposure)    6741.110503     3.0   8.267033  1.803980e-05
# Residual                 640648.961396  2357.0        NaN           NaN
#
# ANOVA for LIN:
#                             sum_sq      df          F        PR(>F)
# C(quantity)               1.331947     3.0  21.955217  5.075939e-14
# C(exposure)               0.257460     1.0  12.731575  3.667090e-04
# C(quantity):C(exposure)   0.717866     3.0  11.832979  1.083082e-07
# Residual                 47.663682  2357.0        NaN           NaN
#
# ANOVA for STR:
#                             sum_sq      df          F        PR(>F)
# C(quantity)               0.660040     3.0   9.587468  2.724900e-06
# C(exposure)               0.007855     1.0   0.342278  5.585734e-01
# C(quantity):C(exposure)   0.744696     3.0  10.817157  4.664990e-07
# Residual                 54.088440  2357.0        NaN           NaN
#
# ANOVA for WOB:
#                             sum_sq      df          F        PR(>F)
# C(quantity)               0.604410     3.0  19.634365  1.430673e-12
# C(exposure)               0.299453     1.0  29.183366  7.245197e-08
# C(quantity):C(exposure)   0.135657     3.0   4.406850  4.250352e-03
# Residual                 24.185379  2357.0        NaN           NaN
#
# ANOVA for BeatCross:
#                                sum_sq      df         F    PR(>F)
# C(quantity)                721.317984     3.0  9.080860  0.000006
# C(exposure)                156.487152     1.0  5.910172  0.015128
# C(quantity):C(exposure)     66.016322     3.0  0.831097  0.476648
# Residual                 62407.691435  2357.0       NaN       NaN

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols
from patsy.contrasts import Helmert

# List of motility parameters
motility_parameters = ['VCL', 'VAP', 'VSL', 'LIN', 'STR', 'WOB', 'BeatCross']

# ANOVA with Helmert contrasts for each motility parameter within each cluster
anova_results = {}
for cluster in df['Spectral Clustering'].unique():
    cluster_data = df[df['Spectral Clustering'] == cluster]
    anova_results_cluster = {}

    for param in motility_parameters:
        # Fitting the model with Helmert contrasts
        formula = f'{param} ~ C(quantity, Helmert()) * C(exposure)'
        model = ols(formula, data=cluster_data).fit()

        # Calculating ANOVA table with contrasts
        anova_table = sm.stats.anova_lm(model, typ=2)
        anova_results_cluster[param] = anova_table

    anova_results[cluster] = anova_results_cluster

# Output ANOVA results
for cluster, results in anova_results.items():
    print(f'ANOVA results for Cluster {cluster}:')
    for param, result in results.items():
        print(f'ANOVA for {param} with Helmert Contrasts:')
        print(result)
        print()  # Adding a blank line for better readability
# Out:
# ANOVA results for Cluster 2:
# ANOVA for VCL with Helmert Contrasts:
#                                           sum_sq      df           F  \
# C(quantity, Helmert())              1.805062e+05     3.0   45.736282
# C(exposure)                         2.336418e+05     1.0  177.598948
# C(quantity, Helmert()):C(exposure)  8.470182e+04     3.0   21.461564
# Residual                            1.006665e+07  7652.0         NaN
#
#                                           PR(>F)
# C(quantity, Helmert())              2.750401e-29
# C(exposure)                         4.522587e-40
# C(quantity, Helmert()):C(exposure)  7.738912e-14
# Residual                                     NaN
#
# ANOVA for VAP with Helmert Contrasts:
#                                           sum_sq      df          F  \
# C(quantity, Helmert())              4.274875e+04     3.0  35.211305
# C(exposure)                         2.121793e+04     1.0  52.430385
# C(quantity, Helmert()):C(exposure)  2.093512e+04     3.0  17.243849
# Residual                            3.096670e+06  7652.0        NaN
#
#                                           PR(>F)
# C(quantity, Helmert())              1.360606e-22
# C(exposure)                         4.891159e-13
# C(quantity, Helmert()):C(exposure)  3.715337e-11
# Residual                                     NaN
#
# ANOVA for VSL with Helmert Contrasts:
#                                           sum_sq      df          F  \
# C(quantity, Helmert())              1.118324e+04     3.0  11.577833
# C(exposure)                         7.961321e+03     1.0  24.726683
# C(quantity, Helmert()):C(exposure)  7.401823e+03     3.0   7.662988
# Residual                            2.463736e+06  7652.0        NaN
#
#                                           PR(>F)
# C(quantity, Helmert())              1.439318e-07
# C(exposure)                         6.750034e-07
# C(quantity, Helmert()):C(exposure)  4.124484e-05
# Residual                                     NaN
#
# ANOVA for LIN with Helmert Contrasts:
#                                         sum_sq      df           F  \
# C(quantity, Helmert())                1.250077     3.0   14.199456
# C(exposure)                           6.495367     1.0  221.339912
# C(quantity, Helmert()):C(exposure)    0.281041     3.0    3.192301
# Residual                            224.553044  7652.0         NaN
#
#                                           PR(>F)
# C(quantity, Helmert())              3.168574e-09
# C(exposure)                         2.250665e-49
# C(quantity, Helmert()):C(exposure)  2.258234e-02
# Residual                                     NaN
#
# ANOVA for STR with Helmert Contrasts:
#                                         sum_sq      df           F  \
# C(quantity, Helmert())                3.743467     3.0   27.800592
# C(exposure)                          12.497471     1.0  278.434777
# C(quantity, Helmert()):C(exposure)    0.163264     3.0    1.212468
# Residual                            343.457982  7652.0         NaN
#
#                                           PR(>F)
# C(quantity, Helmert())              7.126078e-18
# C(exposure)                         1.988239e-61
# C(quantity, Helmert()):C(exposure)  3.034511e-01
# Residual                                     NaN
#
# ANOVA for WOB with Helmert Contrasts:
#                                         sum_sq      df          F  \
# C(quantity, Helmert())                0.275537     3.0   5.453064
# C(exposure)                           0.842252     1.0  50.006165
# C(quantity, Helmert()):C(exposure)    0.274529     3.0   5.433116
# Residual                            128.882410  7652.0        NaN
#
#                                           PR(>F)
# C(quantity, Helmert())              9.644688e-04
# C(exposure)                         1.667895e-12
# C(quantity, Helmert()):C(exposure)  9.920748e-04
# Residual                                     NaN
#
# ANOVA for BeatCross with Helmert Contrasts:
#                                            sum_sq      df          F  \
# C(quantity, Helmert())                2732.547836     3.0  22.283368
# C(exposure)                             40.181521     1.0   0.983016
# C(quantity, Helmert()):C(exposure)     863.941696     3.0   7.045268
# Residual                            312781.204445  7652.0        NaN
#
#                                           PR(>F)
# C(quantity, Helmert())              2.321276e-14
# C(exposure)                         3.214866e-01
# C(quantity, Helmert()):C(exposure)  9.997457e-05
# Residual                                     NaN
#
# ANOVA results for Cluster 3:
# ANOVA for VCL with Helmert Contrasts:
#                                           sum_sq      df          F  \
# C(quantity, Helmert())              6.596845e+04     3.0  21.837866
# C(exposure)                         5.961860e+02     1.0   0.592075
# C(quantity, Helmert()):C(exposure)  5.684965e+03     3.0   1.881922
# Residual                            2.379406e+06  2363.0        NaN
#
#                                           PR(>F)
# C(quantity, Helmert())              6.002378e-14
# C(exposure)                         4.416946e-01
# C(quantity, Helmert()):C(exposure)  1.304880e-01
# Residual                                     NaN
#
# ANOVA for VAP with Helmert Contrasts:
#                                            sum_sq      df          F  \
# C(quantity, Helmert())               12684.666705     3.0  12.391218
# C(exposure)                           2336.772605     1.0   6.848140
# C(quantity, Helmert()):C(exposure)     808.322461     3.0   0.789623
# Residual                            806320.167756  2363.0        NaN
#
#                                           PR(>F)
# C(quantity, Helmert())              4.849762e-08
# C(exposure)                         8.929917e-03
# C(quantity, Helmert()):C(exposure)  4.995850e-01
# Residual                                     NaN
#
# ANOVA for VSL with Helmert Contrasts:
#                                            sum_sq      df          F  \
# C(quantity, Helmert())               11501.012684     3.0  13.256517
# C(exposure)                           3135.313529     1.0  10.841655
# C(quantity, Helmert()):C(exposure)    1568.291405     3.0   1.807674
# Residual                            683359.292203  2363.0        NaN
#
#                                           PR(>F)
# C(quantity, Helmert())              1.395640e-08
# C(exposure)                         1.007043e-03
# C(quantity, Helmert()):C(exposure)  1.436290e-01
# Residual                                     NaN
#
# ANOVA for LIN with Helmert Contrasts:
#                                        sum_sq      df          F        PR(>F)
# C(quantity, Helmert())               0.812815     3.0  12.318514  5.384647e-08
# C(exposure)                          0.284529     1.0  12.936444  3.288573e-04
# C(quantity, Helmert()):C(exposure)   0.266026     3.0   4.031728  7.157519e-03
# Residual                            51.972768  2363.0        NaN           NaN
#
# ANOVA for STR with Helmert Contrasts:
#                                        sum_sq      df         F    PR(>F)
# C(quantity, Helmert())               0.331167     3.0  4.894876  0.002149
# C(exposure)                          0.054622     1.0  2.422052  0.119772
# C(quantity, Helmert()):C(exposure)   0.266468     3.0  3.938575  0.008143
# Residual                            53.290265  2363.0       NaN       NaN
#
# ANOVA for WOB with Helmert Contrasts:
#                                        sum_sq      df          F        PR(>F)
# C(quantity, Helmert())               0.495458     3.0  14.712582  1.713974e-09
# C(exposure)                          0.281363     1.0  25.065101  5.951713e-07
# C(quantity, Helmert()):C(exposure)   0.055588     3.0   1.650671  1.756538e-01
# Residual                            26.525315  2363.0        NaN           NaN
#
# ANOVA for BeatCross with Helmert Contrasts:
#                                           sum_sq      df         F    PR(>F)
# C(quantity, Helmert())                687.773685     3.0  6.978370  0.000113
# C(exposure)                            31.484274     1.0  0.958348  0.327704
# C(quantity, Helmert()):C(exposure)     64.823372     3.0  0.657719  0.578082
# Residual                            77630.788723  2363.0       NaN       NaN
#
# ANOVA results for Cluster 0:
# ANOVA for VCL with Helmert Contrasts:
#                                           sum_sq      df           F  \
# C(quantity, Helmert())              6.541627e+04     3.0   22.400510
# C(exposure)                         1.013655e+05     1.0  104.131858
# C(quantity, Helmert()):C(exposure)  1.219219e+04     3.0    4.174973
# Residual                            5.155308e+06  5296.0         NaN
#
#                                           PR(>F)
# C(quantity, Helmert())              2.081882e-14
# C(exposure)                         3.167869e-24
# C(quantity, Helmert()):C(exposure)  5.821937e-03
# Residual                                     NaN
#
# ANOVA for VAP with Helmert Contrasts:
#                                           sum_sq      df          F  \
# C(quantity, Helmert())              1.676194e+04     3.0  16.814442
# C(exposure)                         1.609327e+03     1.0   4.843101
# C(quantity, Helmert()):C(exposure)  3.233345e+03     3.0   3.243471
# Residual                            1.759822e+06  5296.0        NaN
#
#                                           PR(>F)
# C(quantity, Helmert())              7.209691e-11
# C(exposure)                         2.779994e-02
# C(quantity, Helmert()):C(exposure)  2.107935e-02
# Residual                                     NaN
#
# ANOVA for VSL with Helmert Contrasts:
#                                           sum_sq      df          F  \
# C(quantity, Helmert())              1.020063e+04     3.0  11.008324
# C(exposure)                         2.755196e+03     1.0   8.920065
# C(quantity, Helmert()):C(exposure)  3.761492e+03     3.0   4.059330
# Residual                            1.635808e+06  5296.0        NaN
#
#                                           PR(>F)
# C(quantity, Helmert())              3.339282e-07
# C(exposure)                         2.833463e-03
# C(quantity, Helmert()):C(exposure)  6.838286e-03
# Residual                                     NaN
#
# ANOVA for LIN with Helmert Contrasts:
#                                         sum_sq      df           F  \
# C(quantity, Helmert())                0.944429     3.0   12.723616
# C(exposure)                           3.836808     1.0  155.071774
# C(quantity, Helmert()):C(exposure)    0.351650     3.0    4.737537
# Residual                            131.034383  5296.0         NaN
#
#                                           PR(>F)
# C(quantity, Helmert())              2.775224e-08
# C(exposure)                         4.171898e-35
# C(quantity, Helmert()):C(exposure)  2.651498e-03
# Residual                                     NaN
#
# ANOVA for STR with Helmert Contrasts:
#                                         sum_sq      df           F  \
# C(quantity, Helmert())                0.412098     3.0    6.702163
# C(exposure)                           3.106764     1.0  151.580863
# C(quantity, Helmert()):C(exposure)    0.387326     3.0    6.299287
# Residual                            108.545498  5296.0         NaN
#
#                                           PR(>F)
# C(quantity, Helmert())              1.641414e-04
# C(exposure)                         2.300325e-34
# C(quantity, Helmert()):C(exposure)  2.914054e-04
# Residual                                     NaN
#
# ANOVA for WOB with Helmert Contrasts:
#                                        sum_sq      df          F        PR(>F)
# C(quantity, Helmert())               0.762370     3.0  13.616469  7.583803e-09
# C(exposure)                          1.632529     1.0  87.474401  1.230400e-20
# C(quantity, Helmert()):C(exposure)   0.124769     3.0   2.228464  8.276178e-02
# Residual                            98.838923  5296.0        NaN           NaN
#
# ANOVA for BeatCross with Helmert Contrasts:
#                                            sum_sq      df          F  \
# C(quantity, Helmert())                3323.004298     3.0  26.281650
# C(exposure)                            403.465554     1.0   9.573030
# C(quantity, Helmert()):C(exposure)     376.935665     3.0   2.981185
# Residual                            223205.554585  5296.0        NaN
#
#                                           PR(>F)
# C(quantity, Helmert())              7.208015e-17
# C(exposure)                         1.984858e-03
# C(quantity, Helmert()):C(exposure)  3.014231e-02
# Residual                                     NaN
#
# ANOVA results for Cluster 1:
# ANOVA for VCL with Helmert Contrasts:
#                                           sum_sq      df          F  \
# C(quantity, Helmert())              8.790524e+03     3.0   6.821988
# C(exposure)                         2.050820e+04     1.0  47.746884
# C(quantity, Helmert()):C(exposure)  2.145354e+03     3.0   1.664927
# Residual                            1.330221e+06  3097.0        NaN
#
#                                           PR(>F)
# C(quantity, Helmert())              1.401066e-04
# C(exposure)                         5.862790e-12
# C(quantity, Helmert()):C(exposure)  1.724160e-01
# Residual                                     NaN
#
# ANOVA for VAP with Helmert Contrasts:
#                                            sum_sq      df         F    PR(>F)
# C(quantity, Helmert())                 776.879135     3.0  2.921109  0.032771
# C(exposure)                             14.708817     1.0  0.165918  0.683794
# C(quantity, Helmert()):C(exposure)     632.850896     3.0  2.379555  0.067819
# Residual                            274552.661710  3097.0       NaN       NaN
#
# ANOVA for VSL with Helmert Contrasts:
#                                            sum_sq      df         F    PR(>F)
# C(quantity, Helmert())                 302.220460     3.0  1.202714  0.307195
# C(exposure)                            527.608289     1.0  6.298994  0.012131
# C(quantity, Helmert()):C(exposure)     572.010835     3.0  2.276369  0.077769
# Residual                            259406.955893  3097.0       NaN       NaN
#
# ANOVA for LIN with Helmert Contrasts:
#                                        sum_sq      df          F        PR(>F)
# C(quantity, Helmert())               0.135111     3.0   2.265177  7.892964e-02
# C(exposure)                          0.814848     1.0  40.983453  1.767544e-10
# C(quantity, Helmert()):C(exposure)   0.171499     3.0   2.875233  3.487124e-02
# Residual                            61.575659  3097.0        NaN           NaN
#
# ANOVA for STR with Helmert Contrasts:
#                                        sum_sq      df          F        PR(>F)
# C(quantity, Helmert())               0.172528     3.0   3.317945  1.908767e-02
# C(exposure)                          0.661382     1.0  38.157874  7.375863e-10
# C(quantity, Helmert()):C(exposure)   0.063946     3.0   1.229774  2.972190e-01
# Residual                            53.679593  3097.0        NaN           NaN
#
# ANOVA for WOB with Helmert Contrasts:
#                                        sum_sq      df          F        PR(>F)
# C(quantity, Helmert())               0.126567     3.0   2.350218  7.051542e-02
# C(exposure)                          0.463125     1.0  25.799267  4.012614e-07
# C(quantity, Helmert()):C(exposure)   0.165104     3.0   3.065814  2.692609e-02
# Residual                            55.594574  3097.0        NaN           NaN
#
# ANOVA for BeatCross with Helmert Contrasts:
#                                            sum_sq      df         F    PR(>F)
# C(quantity, Helmert())                 383.278023     3.0  2.806441  0.038269
# C(exposure)                            204.715949     1.0  4.496917  0.034035
# C(quantity, Helmert()):C(exposure)     236.848191     3.0  1.734251  0.157777
# Residual                            140986.649373  3097.0       NaN       NaN
#
# ANOVA results for Cluster 4:
# ANOVA for VCL with Helmert Contrasts:
#                                           sum_sq      df          F  \
# C(quantity, Helmert())              3.907627e+04     3.0  13.471045
# C(exposure)                         1.435905e+02     1.0   0.148503
# C(quantity, Helmert()):C(exposure)  2.283227e+03     3.0   0.787113
# Residual                            2.279031e+06  2357.0        NaN
#
#                                           PR(>F)
# C(quantity, Helmert())              1.025170e-08
# C(exposure)                         7.000049e-01
# C(quantity, Helmert()):C(exposure)  5.010000e-01
# Residual                                     NaN
#
# ANOVA for VAP with Helmert Contrasts:
#                                            sum_sq      df          F  \
# C(quantity, Helmert())               14162.431338     3.0  14.238127
# C(exposure)                           2518.931842     1.0   7.597185
# C(quantity, Helmert()):C(exposure)    2499.543487     3.0   2.512903
# Residual                            781489.760948  2357.0        NaN
#
#                                           PR(>F)
# C(quantity, Helmert())              3.396435e-09
# C(exposure)                         5.890956e-03
# C(quantity, Helmert()):C(exposure)  5.683639e-02
# Residual                                     NaN
#
# ANOVA for VSL with Helmert Contrasts:
#                                            sum_sq      df          F  \
# C(quantity, Helmert())               15479.834425     3.0  18.983860
# C(exposure)                           1780.662087     1.0   6.551202
# C(quantity, Helmert()):C(exposure)    6741.110503     3.0   8.267033
# Residual                            640648.961396  2357.0        NaN
#
#                                           PR(>F)
# C(quantity, Helmert())              3.649569e-12
# C(exposure)                         1.054323e-02
# C(quantity, Helmert()):C(exposure)  1.803980e-05
# Residual                                     NaN
#
# ANOVA for LIN with Helmert Contrasts:
#                                        sum_sq      df          F        PR(>F)
# C(quantity, Helmert())               1.331947     3.0  21.955217  5.075939e-14
# C(exposure)                          0.257460     1.0  12.731575  3.667090e-04
# C(quantity, Helmert()):C(exposure)   0.717866     3.0  11.832979  1.083082e-07
# Residual                            47.663682  2357.0        NaN           NaN
#
# ANOVA for STR with Helmert Contrasts:
#                                        sum_sq      df          F        PR(>F)
# C(quantity, Helmert())               0.660040     3.0   9.587468  2.724900e-06
# C(exposure)                          0.007855     1.0   0.342278  5.585734e-01
# C(quantity, Helmert()):C(exposure)   0.744696     3.0  10.817157  4.664990e-07
# Residual                            54.088440  2357.0        NaN           NaN
#
# ANOVA for WOB with Helmert Contrasts:
#                                        sum_sq      df          F        PR(>F)
# C(quantity, Helmert())               0.604410     3.0  19.634365  1.430673e-12
# C(exposure)                          0.299453     1.0  29.183366  7.245197e-08
# C(quantity, Helmert()):C(exposure)   0.135657     3.0   4.406850  4.250352e-03
# Residual                            24.185379  2357.0        NaN           NaN
#
# ANOVA for BeatCross with Helmert Contrasts:
#                                           sum_sq      df         F    PR(>F)
# C(quantity, Helmert())                721.317984     3.0  9.080860  0.000006
# C(exposure)                           156.487152     1.0  5.910172  0.015128
# C(quantity, Helmert()):C(exposure)     66.016322     3.0  0.831097  0.476648
# Residual                            62407.691435  2357.0       NaN       NaN
